# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [10, 20, 30]
y = [5, 10, 15]

plt.scatter(x, y)
plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
plt.show()

# %%
x = [10, 20, 30, 40, 50]
y = [5, 10, 15, 20, 25]

plt.scatter(x, y)
plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
plt.show()

# %%
def func_liniara(x):
    return x

# %%
func_liniara(10)
# Out:
# 10

# %%
x = [10, 20, 30, 40, 50]
model = list(map(func_liniara, x))
model
# Out:
# [10, 20, 30, 40, 50]

# %%
plt.plot(x, model)

# %%
x = [10, 20, 30, 40, 50]
y = [10, 20, 30, 40, 50]
plt.scatter(x, y, c="red")
plt.plot(x, model)

# %%
x = [10, 20, 30, 40, 50]
y = [5, 10, 15, 20, 25]
plt.scatter(x, y, c="red")

def f(x):
    return x / 2
model = list(map(f, x))

plt.plot(x, model)

# %%
x = [10, 20, 30, 40, 50]
y = [5, 10, 20, 20, 25]
plt.scatter(x, y, c="red")

def f(x):
    return x / 2
model = list(map(f, x))

plt.plot(x, model)

# %%
new_x = 37
f(new_x)
# Out:
# 18.5
