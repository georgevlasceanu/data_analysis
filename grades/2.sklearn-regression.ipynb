# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
regression = make_regression(n_samples=15, n_features=1, noise=3)

# %%
x, y = regression

# %%
x.shape
# Out:
# (15, 1)

# %%
x
# Out:
# array([[-0.69839731],
#        [ 0.14046058],
#        [ 2.25938414],
#        [-1.02608016],
#        [ 1.00231241],
#        [ 0.71796049],
#        [-0.79901657],
#        [ 0.52794819],
#        [ 0.09650505],
#        [-1.68350568],
#        [-0.38326345],
#        [ 0.07322419],
#        [-0.09580455],
#        [-0.65342459],
#        [-0.5688109 ]])

# %%
y.shape
# Out:
# (15,)

# %%
plt.scatter(x, y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model.predict([[-2], [-2.5], [2]])
# Out:
# array([ -84.09145329, -104.90662438,   82.42991539])
