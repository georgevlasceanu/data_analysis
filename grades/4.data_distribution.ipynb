# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 100, 10, dtype=np.int_)
x
# Out:
# array([  0,  11,  22,  33,  44,  55,  66,  77,  88, 100])

# %%
y = x
plt.scatter(x, y)

# %%
y = x ** 2
plt.scatter(x, y)
plt.plot(x, y)

# %%
x = np.linspace(-100, 100, 10, dtype=np.int_)
y = x ** 2
plt.scatter(x, y)
plt.plot(x, y)

# %%
x = np.linspace(-100, 100, 10, dtype=np.int_)
y = x ** 3
plt.scatter(x, y)
plt.plot(x, y)

# %%
x = np.linspace(-100, 100, 10, dtype=np.int_)
y = x ** 4
plt.scatter(x, y)
plt.plot(x, y)

# %%
x = np.linspace(-100, 100, 10, dtype=np.int_)
y = x ** 5
plt.scatter(x, y)
plt.plot(x, y)

# %%
x = np.linspace(-100, 100, 10, dtype=np.int_)
y = x ** 3 - x ** 4
plt.scatter(x, y)
plt.plot(x, y)
